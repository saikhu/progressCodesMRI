# %%
import numpy as np
from nilearn import plotting
from nilearn import image

# %%
imagePath = '/home/usman/Desktop/unomic/progressCodesMRI/Data/BRATS_001.nii'
sampleImage = image.load_img(imagePath)
# Out:
# ---------------------------------------------------------------------------
# ImageFileError                            Traceback (most recent call last)
# /home/usman/Desktop/unomic/progressCodesMRI/NiLearnVizCode.ipynb Cell 2' in <cell line: 2>()
#       <a href='vscode-notebook-cell://ssh-remote%2B106.240.234.115/home/usman/Desktop/unomic/progressCodesMRI/NiLearnVizCode.ipynb#ch0000001vscode-remote?line=0'>1</a> imagePath = '/home/usman/Desktop/unomic/progressCodesMRI/Data/BRATS_001.nii'
# ----> <a href='vscode-notebook-cell://ssh-remote%2B106.240.234.115/home/usman/Desktop/unomic/progressCodesMRI/NiLearnVizCode.ipynb#ch0000001vscode-remote?line=1'>2</a> sampleImage = image.load_img(imagePath)
#
# File ~/anaconda3/envs/niedu/lib/python3.8/site-packages/nilearn/image/image.py:1246, in load_img(img, wildcards, dtype)
# ...

# %%
plotting.plot_glass_brain(sampleImage)
