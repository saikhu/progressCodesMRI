# %%
! pip install pandas openpyxl
# Out:
# Requirement already satisfied: pandas in /home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages (1.4.2)
# Collecting openpyxl
#   Downloading openpyxl-3.0.9-py2.py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.2/242.2 KB 671.0 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy>=1.21.0 in /home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages (from pandas) (1.22.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages (from pandas) (2022.1)
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: six>=1.5 in /home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.0.9

# %%
import os 
import dicom2nifti
from nipype.interfaces.dcm2nii import Dcm2niix

# %%
dirPath = "/raid/users/usman/unomic_data/00_origData/01_P"
destDir = "/raid/users/usman/unomic_data/00_origData/01_P_Classification"
osDir = os.walk(dirPath)
osDir
# Out:
# <generator object _walk at 0x7fccdaf34580>

# %%
import pandas as pd
labelFile = pd.read_excel(
    "/raid/users/usman/unomic_data/00_origData/01_P.xlsx")
labelFile
# Out:
#        등록순서 subject No.   Unnamed: 2    연령 남: 0\n여: 1  교육연수 \n기입  \
# 0     order         V번호  subject no.   NaN     gender  education
# 1         1          V1  01_P_0001_1  84.0          1         16
# 2         2          V2  01_P_0001_2  85.0          1         16
# 3         3          V3  01_P_0001_3  86.0          1         16
# 4         4          V4  01_P_0001_4  87.0          1         16
# ...     ...         ...          ...   ...        ...        ...
# 3654    NaN         NaN          NaN   NaN        NaN        NaN
# 3655    NaN         NaN          NaN   NaN        NaN        NaN
# 3656    NaN         NaN          NaN   NaN        NaN        NaN
# 3657    NaN         NaN          NaN   NaN        NaN        NaN
# 3658    NaN         NaN          NaN   NaN        NaN        NaN
#
#       Normal=0,    Early MCI=1, Late MCI=2,   Dementia=3  \
# 0                                                   NaN
# 1                                                   0.0
# 2                                                   2.0
# 3                                                   0.0
# 4                                                   0.0
# ...                                                 ...
# 3654                                                NaN
# 3655                                                NaN
# 3656                                                NaN
# 3657                                                NaN
# 3658                                                0.0
#
#       Dx    AD=0, VD=1, FTD=2, PDD=3, DLBD=4, unknown=5  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3654                                                NaN
# 3655                                                NaN
# 3656                                                NaN
# 3657                                                NaN
# 3658                                                NaN
#
#       Co-Dx  AD=0, VD=1, FTD=2, PDD=3, DLBD=4, unknown=5  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3654                                                NaN
# 3655                                                NaN
# 3656                                                NaN
# 3657                                                NaN
# 3658                                                NaN
#
#      Converting 여부  converted =1 non converted=0   ... COWAT A 점수_1 (%ile)  \
# 0                                             NaN  ...      COWAT_animal_p
# 1                                             n.a  ...                 NaN
# 2                                             n.a  ...                 NaN
# 3                                             n.a  ...                 NaN
# 4                                             n.a  ...                 NaN
# ...                                           ...  ...                 ...
# 3654                                          NaN  ...                 NaN
# 3655                                          NaN  ...                 NaN
# 3656                                          NaN  ...                 NaN
# 3657                                          NaN  ...                 NaN
# 3658                                          n.a  ...                 NaN
#
#       COWAT A z-score_1  COWAT S 점수_1 (%ile)    COWAT S z-score_1  \
# 0        COWAT_animal_z  COWAT_supermarket_p  COWAT_supermarket_z
# 1                   NaN                  NaN                  NaN
# 2                   NaN                  NaN                  NaN
# 3                   NaN                  NaN                  NaN
# 4                   NaN                  NaN                  NaN
# ...                 ...                  ...                  ...
# 3654                NaN                  NaN                  NaN
# 3655                NaN                  NaN                  NaN
# 3656                NaN                  NaN                  NaN
# 3657                NaN                  NaN                  NaN
# 3658                NaN                  NaN                  NaN
#
#                COWAT P 점수_1 (%ile)             COWAT P z-score_1  \
# 0     COWAT_phonemic_total_score_p  COWAT_phonemic_total_score_z
# 1                              NaN                           NaN
# 2                              NaN                           NaN
# 3                              NaN                           NaN
# 4                              NaN                           NaN
# ...                            ...                           ...
# 3654                           NaN                           NaN
# 3655                           NaN                           NaN
# 3656                           NaN                           NaN
# 3657                           NaN                           NaN
# 3658                           NaN                           NaN
#
#       K-TMT-E:B 점수_1 (%ile)  K-TMT-E:B z-score_1  \
# 0          K_TMT_E_B_time_p     K_TMT_E_B_time_z
# 1                       NaN                  NaN
# 2                       NaN                  NaN
# 3                       NaN                  NaN
# 4                       NaN                  NaN
# ...                     ...                  ...
# 3654                    NaN                  NaN
# 3655                    NaN                  NaN
# 3656                    NaN                  NaN
# 3657                    NaN                  NaN
# 3658                    NaN                  NaN
#
#                         K-CWST:CR 점수_1 (%ile)  \
# 0     StroopTest_Colorreading_Time_per_item_p
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 3654                                      NaN
# 3655                                      NaN
# 3656                                      NaN
# 3657                                      NaN
# 3658                                      NaN
#
#                           K-CWST:CR z-score_1
# 0     StroopTest_Colorreading_Time_per_item_z
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 3654                                      NaN
# 3655                                      NaN
# 3656                                      NaN
# 3657                                      NaN
# 3658                                      NaN
#
# [3659 rows x 78 columns]

# %%
label = labelFile.iloc[3,6]
label
# len(labelFile)
# Out:
# 0.0

# %%
a = os.path.join(destDir, labelFile.iloc[3,2] + '_' + str(int(labelFile.iloc[3, 6])) + '.nii')
a
# Out:
# '/raid/users/usman/unomic_data/00_origData/01_P_Classification/01_P_0001_3_0.nii'

# %%
! pip install nipype
# Out:
# Collecting nipype
#   Downloading nipype-1.7.1-py3-none-any.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 8.9 MB/s eta 0:00:0000:0100:01
# Collecting simplejson>=3.8.0
#   Downloading simplejson-3.17.6-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.1/137.1 KB 11.1 MB/s eta 0:00:00
# Collecting networkx>=2.0
#   Using cached networkx-2.8-py3-none-any.whl (2.0 MB)
# Collecting pydot>=1.2.3
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: scipy>=0.14 in /home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages (from nipype) (1.8.0)
# Collecting click>=6.6.0
#   Using cached click-8.1.2-py3-none-any.whl (96 kB)
# Collecting prov>=1.5.2
#   Downloading prov-2.0.0-py3-none-any.whl (421 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.5/421.5 KB 10.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: packaging in /home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages (from nipype) (21.3)
# Collecting filelock>=3.0.0
#   Using cached filelock-3.6.0-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: python-dateutil>=2.2 in /home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages (from nipype) (2.8.2)
# Collecting rdflib>=5.0.0
#   Downloading rdflib-6.1.1-py3-none-any.whl (482 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 482.8/482.8 KB 10.0 MB/s eta 0:00:00a 0:00:01
# Collecting etelemetry>=0.2.0
#   Downloading etelemetry-0.3.0-py3-none-any.whl (6.3 kB)
# Requirement already satisfied: numpy>=1.15.3 in /home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages (from nipype) (1.22.3)
# Requirement already satisfied: nibabel>=2.1.0 in /home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages (from nipype) (3.2.2)
# Collecting traits!=5.0,>=4.6
#   Downloading traits-6.3.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 9.7 MB/s eta 0:00:00:00:0100:01
# Collecting ci-info>=0.2
#   Downloading ci_info-0.2.0-py3-none-any.whl (6.9 kB)
# Collecting requests
#   Using cached requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Requirement already satisfied: setuptools in /home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages (from nibabel>=2.1.0->nipype) (62.0.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages (from packaging->nipype) (3.0.7)
# Collecting lxml>=3.3.5
#   Downloading lxml-4.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 9.8 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: six>=1.5 in /home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages (from python-dateutil>=2.2->nipype) (1.16.0)
# Collecting isodate
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 KB 10.9 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17
#   Using cached certifi-2021.10.8-py2.py3-none-any.whl (149 kB)
# Collecting charset-normalizer~=2.0.0
#   Using cached charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.3-py3-none-any.whl (61 kB)
# Installing collected packages: certifi, urllib3, traits, simplejson, pydot, networkx, lxml, isodate, idna, filelock, click, ci-info, charset-normalizer, requests, rdflib, prov, etelemetry, nipype
# Successfully installed certifi-2021.10.8 charset-normalizer-2.0.12 ci-info-0.2.0 click-8.1.2 etelemetry-0.3.0 filelock-3.6.0 idna-3.3 isodate-0.6.1 lxml-4.8.0 networkx-2.8 nipype-1.7.1 prov-2.0.0 pydot-1.4.2 rdflib-6.1.1 requests-2.27.1 simplejson-3.17.6 traits-6.3.2 urllib3-1.26.9

# %%
# for i in range(len(labelFile)):
converter = Dcm2niix()
for i in range(10): 
    label = labelFile.iloc[i+1, 2]
    rpath = os.path.join(dirPath, label)
    t1path = os.path.join(rpath, "T1")
    if os.path.isdir(rpath):
        # print(rpath)
        if os.path.isdir(t1path):
            print("Found T1")
            if len(t1path) == 0:
                print("Empty directory")
            else:
                try:
                    output_file = os.path.join(
                        destDir, labelFile.iloc[i+1, 2] + '_' + str(int(labelFile.iloc[i+1, 6])) + '.nii')
                    converter.cmdline
                    # ! dcm2niix - z n - v y - s n - o / t1path / -i / raid/users/usman/unomic_data/00_origData/01_N/01_N_DCM/
                    # print("Not empty directory")
                except AssertionError as error:
                    print(error)

    else:
        print("Not found")
# Out:
# Not found
# Not found
# Not found
# Not found
# Not found
# Found T1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/usman/Desktop/unomic/progressCodesMRI/unomic_al_data_conv.ipynb Cell 7' in <cell line: 2>()
#      <a href='vscode-notebook-cell://ssh-remote%2B106.240.234.115/home/usman/Desktop/unomic/progressCodesMRI/unomic_al_data_conv.ipynb#ch0000001vscode-remote?line=12'>13</a> try:
#      <a href='vscode-notebook-cell://ssh-remote%2B106.240.234.115/home/usman/Desktop/unomic/progressCodesMRI/unomic_al_data_conv.ipynb#ch0000001vscode-remote?line=13'>14</a>     output_file = os.path.join(
#      <a href='vscode-notebook-cell://ssh-remote%2B106.240.234.115/home/usman/Desktop/unomic/progressCodesMRI/unomic_al_data_conv.ipynb#ch0000001vscode-remote?line=14'>15</a>         destDir, labelFile.iloc[i+1, 2] + '_' + str(int(labelFile.iloc[i+1, 6])) + '.nii')
# ---> <a href='vscode-notebook-cell://ssh-remote%2B106.240.234.115/home/usman/Desktop/unomic/progressCodesMRI/unomic_al_data_conv.ipynb#ch0000001vscode-remote?line=15'>16</a>     dicom2nifti.dicom_series_to_nifti(
#      <a href='vscode-notebook-cell://ssh-remote%2B106.240.234.115/home/usman/Desktop/unomic/progressCodesMRI/unomic_al_data_conv.ipynb#ch0000001vscode-remote?line=16'>17</a>         t1path, output_file, reorient_nifti=True)
#      <a href='vscode-notebook-cell://ssh-remote%2B106.240.234.115/home/usman/Desktop/unomic/progressCodesMRI/unomic_al_data_conv.ipynb#ch0000001vscode-remote?line=17'>18</a>     # print("Not empty directory")
#      <a href='vscode-notebook-cell://ssh-remote%2B106.240.234.115/home/usman/Desktop/unomic/progressCodesMRI/unomic_al_data_conv.ipynb#ch0000001vscode-remote?line=18'>19</a> except AssertionError as error:
#
# File ~/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/convert_dicom.py:78, in dicom_series_to_nifti(original_dicom_directory, output_file, reorient_nifti)
#      <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/convert_dicom.py?line=73'>74</a>     shutil.copytree(original_dicom_directory, dicom_directory)
#      <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/convert_dicom.py?line=75'>76</a>     dicom_input = common.read_dicom_directory(dicom_directory)
# ---> <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/convert_dicom.py?line=77'>78</a>     return dicom_array_to_nifti(dicom_input, output_file, reorient_nifti)
#      <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/convert_dicom.py?line=79'>80</a> except AttributeError as exception:
#      <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/convert_dicom.py?line=80'>81</a>     raise exception
#
# File ~/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/convert_dicom.py:112, in dicom_array_to_nifti(dicom_list, output_file, reorient_nifti)
#      <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/convert_dicom.py?line=88'>89</a> """ Converts dicom single series (see pydicom) to nifty, mimicking SPM
#      <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/convert_dicom.py?line=89'>90</a>
#      <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/convert_dicom.py?line=90'>91</a> Examples: See unit test
#    (...)
#     <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/convert_dicom.py?line=108'>109</a> :param dicom_list: list with uncompressed dicom objects as read by pydicom
#     <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/convert_dicom.py?line=109'>110</a> """
#     <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/convert_dicom.py?line=110'>111</a> # copy files so we can can modify without altering the original
# --> <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/convert_dicom.py?line=111'>112</a> if not are_imaging_dicoms(dicom_list):
#     <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/convert_dicom.py?line=112'>113</a>     raise ConversionValidationError('NON_IMAGING_DICOM_FILES')
#     <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/convert_dicom.py?line=114'>115</a> vendor = _get_vendor(dicom_list)
#
# File ~/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/convert_dicom.py:151, in are_imaging_dicoms(dicom_input)
#     <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/convert_dicom.py?line=142'>143</a> """
#     <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/convert_dicom.py?line=143'>144</a> This function will check the dicom headers to see which type of series it is
#     <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/convert_dicom.py?line=144'>145</a> Possibilities are fMRI, DTI, Anatomical (if no clear type is found anatomical is used)
#     <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/convert_dicom.py?line=145'>146</a>
#     <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/convert_dicom.py?line=146'>147</a> :param dicom_input: directory with dicom files or a list of dicom objects
#     <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/convert_dicom.py?line=147'>148</a> """
#     <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/convert_dicom.py?line=149'>150</a> # if it is philips and multiframe dicom then we assume it is ok
# --> <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/convert_dicom.py?line=150'>151</a> if common.is_philips(dicom_input) or common.is_siemens(dicom_input):
#     <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/convert_dicom.py?line=151'>152</a>     if common.is_multiframe_dicom(dicom_input):
#     <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/convert_dicom.py?line=152'>153</a>         return True
#
# File ~/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/common.py:102, in is_philips(dicom_input)
#      <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/common.py?line=95'>96</a> """
#      <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/common.py?line=96'>97</a> Use this function to detect if a dicom series is a philips dataset
#      <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/common.py?line=97'>98</a>
#      <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/common.py?line=98'>99</a> :param dicom_input: directory with dicom files for 1 scan of a dicom_header
#     <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/common.py?line=99'>100</a> """
#     <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/common.py?line=100'>101</a> # read dicom header
# --> <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/common.py?line=101'>102</a> header = dicom_input[0]
#     <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/common.py?line=103'>104</a> if 'Manufacturer' not in header or 'Modality' not in header:
#     <a href='file:///home/usman/anaconda3/envs/dcm2bids/lib/python3.10/site-packages/dicom2nifti/common.py?line=104'>105</a>     return False  # we try generic conversion in these cases
#
# IndexError: list index out of range
